# %%
print('Type\n 1: For list\n 2: For tuple\n 3: For set\n 4: For dictionary\n 5: Exit')
a=int(input('enter number of your choice: '))

if a==1:
        l1=list(eval(input('give list: ')))
        print('Type \n 1: for addition\n 2: to delete')
        b=int(input('enter number of your choice: '))
        if b==1:
                print('Insertion can be made by 3 methods\n 1: append() \n 2: insert() \n 3: extend()')
                c=int(input('enter number of your choice: '))
                if c==1:
                        l1.append(int(input('add value you want to add: ')))
                        print(l1,'append adds new element at the end')                
                elif c==2:
                        l=int(input("enter index at which you want to add element: "))
                        z=input("enter element you want to add: ")
                        l1.insert(l,z)
                        print(l1)
                else:
                        l2=list(eval(input('give list')))
                        l1.extend(l2)
                        print(l1)
        else:
                print('To delete we have 4 methods\n 1:remove \n 2:pop \n 3:clear\n 4:del')
                d=int(input('enter value of your choice: '))
                if d==1:
                    l1.remove(int(input('put value that you want to remove: ')))
                    print(l1)
                elif d==2:
                        l1.pop(int(input('give index of the value you want to remove: ')))
                        print(l1)
                elif d==3:
                        l1.clear()
                        print(l1 ,'clear removes all elements but keeps structure: ')
                else: 
                        del l1
                        print('del removes structure of list from the memory')
                                        
elif a==2:
        t1=tuple(eval(input('enter tuple: ')))
        print(t1)
        print('Type \n 1: for addition\n 2: to delete')
        e=int(input('enter number of your choice: '))
        if e==1:
                print('Insertion can be made by 2 methods \n 1: append() \n 2: insert(to add value at specific position)')
                f=int(input('enter number of your choice: '))
                if f==1:
                    l2=list(t1)
                    l2.append(int(input('add value you want to add: ')))
                    t1=tuple(l2)
                    print(t1,'append adds new element at the end')
                else:
                    l3=list(t1)
                    l3.insert(0,8)
                    t1=tuple(l3)
                    print(t1)
        else:
            print('To delete we have 3 methods\n 1:remove \n 2:pop \n 3:clear')
            g=int(input('chose method of delete: '))
            if g==1:
                l4=list(t1)
                l4.remove(int(input('put value that you want to remove: ')))
                t1=tuple(l4)
                print(t1)
            elif g==2:
                l5=list(t1)
                l5.pop(int(input('give index of the value you want to remove: ')))
                t1=tuple(l5)
                print(t1)
            else:
                l6=list(t1)
                l6.clear()
                t1=tuple(l6)
                print(t1,'removes all values')
elif a==3:
        s1=set(eval(input('enter set1 s1: ')))
        print(s1)
        s2=set(eval(input('enter set2 s2: ')))
        print(s2)
        print('Type\n 1: For union\n 2:For intersection \n 3: For difference \n 4: for symmetric difference')
        h=int(input('enter number of your choice: '))
        if h==1:
                print('type\n  1:For method 1 (|) \n 2: For method 2 (s1.union(s2)')
                i=int(input('enter value of your choice: '))
                if i==1:
                    print(s1|s2)
                else:
                    print(s1.union(s2))
        elif h==2:
                print('type\n 1:For method 1(&) \n 2:For method 2 s1.intersection(s2)')
                j=int(input('enter value of your choice: '))
                if j==1:
                    print(s1&s2)
                else:
                    print(s1.intersection(s2))
        elif h==3:
                print(s1-s2 ,'removes common elements and gives all elements from left set')
        else:
            print(s1^s2,'removed common elements from both sets and united both sets')
elif a==4:
        z=int(input('enter no of key value pairs: '))
        d=dict(input('enter a key and value: ').split()for i in range(z))
        print(d)
        print('chose\n 1: For addition\n 2: To access\n 3: To delete')
        y=int(input('enter number of your choice: '))
        if y==1:
                print('1: To add single key:value pair 2:To add multiple key:value pairs')
                p=int(input('enter value to choose: '))
                if p==1:
                    key=input('enter key: ')
                    value=input('enter value: ')
                    d[key]=value
                    print(d)
                else:
                    q=int(input(' enter number of key value pair u want to add: '))
                    for i in range(1,n):
                        key=input('enter key: ')
                        value=input('enter value: ')
                        d[key]=value
                        print(d)
        elif y==2:
            print('1: To access all keys from dictionary\n 2: To access all values from dictionary\n3: To access all key:value pairs \n4: get method\n')
            n=int(input('enter number to choose what u want to access: '))
            if n==1:
                 print(d.keys())
            elif n==2:
                print(d.values())
            elif n==3:
                print(d.items())
            else:
                g=input("enter key whose value u want to access")
                print(d.get(g))
        else:
            print('we have 3 methods to delete\n 1:pop (allows you to remove specific key and value pair)\n  2:popitem(removes randomly)\n 3:clear()')
            o=int(input('chose number of your choice: '))
            if o==1:
                d.pop(input('enter key u want to remove: '))
                print(d,'mentioned key and its value removed')
            elif o==2:
                d.popitem()
                print(d)
            else: 
                d.clear()
                print(d,'removes all key value pairs')
else:
    print('exit')
# Out:
# Type
#  1: For list
#  2: For tuple
#  3: For set
#  4: For dictionary
#  5: Exit
# enter number of your choice: 1
# give list: 1,2,3,4,5,7
# Type
#  1: for addition
#  2: to delete
# enter number of your choice: 2
# To delete we have 4 methods
#  1:remove
#  2:pop
#  3:clear
#  4:del
# enter value of your choice: 2
# give index of the value you want to remove: 3
# [1, 2, 3, 5, 7]
